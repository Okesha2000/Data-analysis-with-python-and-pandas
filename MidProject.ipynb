# %% [markdown]
# <a href="https://colab.research.google.com/github/Okesha2000/Data-analysis-with-python-and-pandas/blob/main/MidProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mid-Course Project
#
# Hi There, and thanks for your help. If you're reading this you've been selected to help on a secret initiative.
#
# You will be helping us analyze a portion of data from a company we want to acquire, which could greatly improve the fortunes of Maven Mega Mart.
#
# We'll be working with `project_transactions.csv` and briefly take a look at `product.csv`.
#
# First, read in the transactions data and explore it.
#
# * Take a look at the raw data, the datatypes, and cast `DAY`, `QUANTITY`, `STORE_ID`, and `WEEK_NO` columns to the smallest appropriate datatype. Check the memory reduction by doing so.
# * Is there any missing data?
# * How many unique households and products are there in the data? The fields household_key and Product_ID will help here.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
trans = pd.read_csv('/content/project_transactions.csv',
dtype = {'DAY':'int16',
         'QUANTITY':'int32',
         'STORE_ID':'int32',
         'WEEK_NO':'int8'})
trans.head(3)
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1364  26984896261    1      842930         1         2.19
# 1           1364  26984896261    1      897044         1         2.99
# 2           1364  26984896261    1      920955         1         3.09
#
#    STORE_ID  RETAIL_DISC  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0     31742          0.0        1          0.0                0.0
# 1     31742         -0.4        1          0.0                0.0
# 2     31742          0.0        1          0.0                0.0

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2146311 entries, 0 to 2146310
# Data columns (total 11 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   household_key      int64
#  1   BASKET_ID          int64
#  2   DAY                int16
#  3   PRODUCT_ID         int64
#  4   QUANTITY           int32
#  5   SALES_VALUE        float64
#  6   STORE_ID           int32
#  7   RETAIL_DISC        float64
#  8   WEEK_NO            int8
#  9   COUPON_DISC        float64
#  10  COUPON_MATCH_DISC  float64
# dtypes: float64(4), int16(1), int32(2), int64(3), int8(1)
# memory usage: 137.1 MB

# %%
trans.describe(include ='all').round(2)
# Out:
#        household_key     BASKET_ID         DAY   PRODUCT_ID    QUANTITY  \
# count     2146311.00  2.146311e+06  2146311.00   2146311.00  2146311.00
# mean         1056.23  3.404897e+10      389.51   2884714.94      100.97
# std           605.01  4.723748e+09      190.05   3831949.29     1152.36
# min             1.00  2.698490e+10        1.00     25671.00        0.00
# 25%           548.00  3.040798e+10      229.00    917231.00        1.00
# 50%          1042.00  3.281176e+10      392.00   1027960.00        1.00
# 75%          1581.00  4.012804e+10      555.00   1132771.00        1.00
# max          2099.00  4.230536e+10      711.00  18316298.00    89638.00
#
#        SALES_VALUE    STORE_ID  RETAIL_DISC     WEEK_NO  COUPON_DISC  \
# count   2146311.00  2146311.00   2146311.00  2146311.00   2146311.00
# mean          3.11     3267.94        -0.53       56.33        -0.02
# std           4.19     9122.39         1.23       27.15         0.21
# ...

# %%
trans.isna().sum()
# Out:
# household_key        0
# BASKET_ID            0
# DAY                  0
# PRODUCT_ID           0
# QUANTITY             0
# SALES_VALUE          0
# STORE_ID             0
# RETAIL_DISC          0
# WEEK_NO              0
# COUPON_DISC          0
# COUPON_MATCH_DISC    0
# dtype: int64

# %%
trans.loc[:,['household_key','PRODUCT_ID']].nunique()
# Out:
# household_key     2099
# PRODUCT_ID       84138
# dtype: int64

# %% [markdown]
# ## Column Creation
#
# Create two columns:
#
# * A column that captures the `total_discount` by row (sum of `RETAIL_DISC`, `COUPON_DISC`)
# * The percentage disount (`total_discount` / `SALES_VALUE`). Make sure this is positive (try `.abs()`).
# * If the percentage discount is greater than 1, set it equal to 1. If it is less than 0, set it to 0.
# * Drop the individual discount columns (`RETAIL_DISC`, `COUPON_DISC`, `COUPON_MATCH_DISC`).
#
# Feel free to overwrite the existing transaction DataFrame after making the modifications above.

# %%
trans = trans.assign(
    total_discount = trans['RETAIL_DISC']+trans['COUPON_DISC'],
    disc_percentage = (lambda x:(x['total_discount'].abs()/x['SALES_VALUE']).abs())
).drop(['RETAIL_DISC', 'COUPON_MATCH_DISC','COUPON_DISC'], axis = 1)

trans.head(3)
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1364  26984896261    1      842930         1         2.19
# 1           1364  26984896261    1      897044         1         2.99
# 2           1364  26984896261    1      920955         1         3.09
#
#    STORE_ID  WEEK_NO  total_discount  disc_percentage
# 0     31742        1             0.0         0.000000
# 1     31742        1            -0.4         0.133779
# 2     31742        1             0.0         0.000000

# %%
trans['disc_percentage'] = np.where(trans['disc_percentage'] >1, 1,np.where(trans['disc_percentage'] <0, 0,trans['disc_percentage']))
trans.head(5)
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1364  26984896261    1      842930         1         2.19
# 1           1364  26984896261    1      897044         1         2.99
# 2           1364  26984896261    1      920955         1         3.09
# 3           1364  26984896261    1      937406         1         2.50
# 4           1364  26984896261    1      981760         1         0.60
#
#    STORE_ID  WEEK_NO  total_discount  disc_percentage
# 0     31742        1            0.00         0.000000
# 1     31742        1           -0.40         0.133779
# 2     31742        1            0.00         0.000000
# 3     31742        1           -0.99         0.396000
# 4     31742        1           -0.79         1.000000

# %% [markdown]
# # ## Overall Statistics
#
# Calculate:
#
# * The total sales (sum of `SALES_VALUE`),
# * Total discount (sum of `total_discount`)
# * Overall percentage discount (sum of total_discount / sum of sales value)
# * Total quantity sold (sum of `QUANTITY`).
# * Max quantity sold in a single row. Inspect the row as well. Does this have a high discount percentage?
# * Total sales value per basket (sum of sales value / nunique basket_id).
# * Total sales value per household (sum of sales value / nunique household_key).

# %%
tot_sales = trans.loc[:,'SALES_VALUE'].sum()
tot_sales
# Out:
# 6666243.499999999

# %%
tot_disc = trans.loc[:,'total_discount'].sum()
tot_disc
# Out:
# -1178658.0799999998

# %%
overall_per_disc = (tot_disc)/tot_sales
overall_per_disc
# Out:
# -0.1768099350106248

# %%
tot_quant = trans['QUANTITY'].sum()
tot_quant
# Out:
# 216713611

# %% [markdown]
# ### M1

# %%
maxim = trans['QUANTITY'].max()
trans[trans['QUANTITY'] == maxim]
# Out:
#          household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 1442095            630  34749153595  503     6534178     89638        250.0
#
#          STORE_ID  WEEK_NO  total_discount  disc_percentage
# 1442095       384       73          -13.45           0.0538

# %% [markdown]
# ### M2

# %%
trans.loc[trans['QUANTITY'].argmax()]
# Out:
# household_key      6.300000e+02
# BASKET_ID          3.474915e+10
# DAY                5.030000e+02
# PRODUCT_ID         6.534178e+06
# QUANTITY           8.963800e+04
# SALES_VALUE        2.500000e+02
# STORE_ID           3.840000e+02
# WEEK_NO            7.300000e+01
# total_discount    -1.345000e+01
# disc_percentage    5.380000e-02
# Name: 1442095, dtype: float64

# %%
tot_val = tot_sales / (trans['BASKET_ID'].nunique())
tot_val
# Out:
# 28.61797938516092

# %%
tot_val2 = tot_sales / (trans['household_key'].nunique())
tot_val2
# Out:
# 3175.9140066698424

# %% [markdown]
# ## Household Analysis
#
# * Plot the distribution of total sales value purchased at the household level.
# * What were the top 10 households by quantity purchased?
# * What were the top 10 households by sales value?
# * Plot the total sales value for our top 10 households by value, ordered from highest to lowest.

# %%
trans.groupby('household_key')['SALES_VALUE'].sum().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
top_10_quant = trans.groupby('household_key')['QUANTITY'].sum().sort_values(ascending = False).iloc[0:10]
top_10_quant
# Out:
# household_key
# 1023    4479917
# 755     3141769
# 1609    2146715
# 13      1863829
# 1430    1741892
# 1527    1734632
# 1762    1669880
# 707     1640193
# 1029    1496204
# 1314    1492863
# Name: QUANTITY, dtype: int32

# %%
top_10_sales= trans.groupby('household_key')['SALES_VALUE'].sum().sort_values(ascending = False).iloc[0:10]
top_10_sales
# Out:
# household_key
# 1023    38319.79
# 1609    27859.68
# 1453    21661.29
# 1430    20352.99
# 718     19299.86
# 707     19194.42
# 1653    19153.75
# 1111    18894.72
# 982     18790.34
# 400     18494.14
# Name: SALES_VALUE, dtype: float64

# %%
trans.groupby('household_key')['SALES_VALUE'].sum().sort_values(ascending = False).iloc[0:10].plot.bar()
# Out:
# <Axes: xlabel='household_key'>

# %% [markdown]
# ## Product Analysis
#
# * Which products had the most sales by sales_value? Plot  a horizontal bar chart.
# * Did the top 10 selling items have a higher than average discount rate?
# * What was the most common `PRODUCT_ID` among rows with the households in our top 10 households by sales value?
# * Look up the names of the  top 10 products by sales in the `products.csv` dataset.
# * Look up the product name of the item that had the highest quantity sold in a single row.

# %%
trans.groupby('PRODUCT_ID')['SALES_VALUE'].sum().sort_values(ascending= False).head(1)
# Out:
# PRODUCT_ID
# 6534178    420154.13
# Name: SALES_VALUE, dtype: float64

# %%
top_10_prod = trans.groupby('PRODUCT_ID')['SALES_VALUE'].sum().sort_values(ascending = False).iloc[0:10]
top_10_prod
# Out:
# PRODUCT_ID
# 6534178    420154.13
# 6533889     42339.31
# 1029743     33894.75
# 1082185     24149.79
# 6533765     23831.14
# 6534166     23755.70
# 1106523     22931.01
# 916122      22749.02
# 995242      21229.72
# 5569230     20051.95
# Name: SALES_VALUE, dtype: float64

# %%
top_hh_products = trans.query("household_key in @top_10_sales.index").loc[:,'PRODUCT_ID'].value_counts().iloc[:10]
top_hh_products
# Out:
# PRODUCT_ID
# 1082185    576
# 1029743    573
# 6534178    561
# 6533889    418
# 1127831    230
# 951590     202
# 860776     184
# 1106523    178
# 981760     174
# 9677202    168
# Name: count, dtype: int64

# %%
products = pd.read_csv('/content/product.csv')
products
# Out:
#        PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND  \
# 0           25671             2       GROCERY  National
# 1           26081             2  MISC. TRANS.  National
# 2           26093            69        PASTRY   Private
# 3           26190            69       GROCERY   Private
# 4           26355            69       GROCERY   Private
# ...           ...           ...           ...       ...
# 92348    18293142          6384       DRUG GM  National
# 92349    18293439          6393       DRUG GM  National
# 92350    18293696          6406       DRUG GM  National
# 92351    18294080          6442       DRUG GM  National
# 92352    18316298           764       GROCERY  National
#
#                  COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0                      FRZN ICE          ICE - CRUSHED/CUBED
# 1      NO COMMODITY DESCRIPTION  NO SUBCOMMODITY DESCRIPTION
# 2                         BREAD         BREAD:ITALIAN/FRENCH
# ...

# %%
products.query("PRODUCT_ID in @top_hh_products.index ")
# Out:
#        PRODUCT_ID  MANUFACTURER       DEPARTMENT     BRAND  \
# 10630      860776             2          PRODUCE  National
# 20973      951590           910          GROCERY  National
# 24250      981760            69          GROCERY   Private
# 29657     1029743            69          GROCERY   Private
# 35576     1082185             2          PRODUCE  National
# 38262     1106523            69          GROCERY   Private
# 40600     1127831          5937          PRODUCE  National
# 57181     6533889            69  MISC SALES TRAN   Private
# 57221     6534178            69        KIOSK-GAS   Private
# 68952     9677202            69          GROCERY   Private
#
#                 COMMODITY_DESC      SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 10630  VEGETABLES - ALL OTHERS               CUCUMBERS                36 CT
# 20973   BAKED BREAD/BUNS/ROLLS  MAINSTREAM WHITE BREAD                20 OZ
# 24250                     EGGS          EGGS - X-LARGE                 1 DZ
# ...

# %%
products.query("PRODUCT_ID in @top_10_prod.index ")
# Out:
#        PRODUCT_ID  MANUFACTURER       DEPARTMENT     BRAND  \
# 16863      916122          4314             MEAT  National
# 25754      995242            69          GROCERY   Private
# 29657     1029743            69          GROCERY   Private
# 35576     1082185             2          PRODUCE  National
# 38262     1106523            69          GROCERY   Private
# 53097     5569230          1208          GROCERY  National
# 57171     6533765            69        KIOSK-GAS   Private
# 57181     6533889            69  MISC SALES TRAN   Private
# 57216     6534166            69  MISC SALES TRAN   Private
# 57221     6534178            69        KIOSK-GAS   Private
#
#             COMMODITY_DESC              SUB_COMMODITY_DESC  \
# 16863              CHICKEN         CHICKEN BREAST BONELESS
# 25754  FLUID MILK PRODUCTS           FLUID MILK WHITE ONLY
# 29657  FLUID MILK PRODUCTS           FLUID MILK WHITE ONLY
# 35576       TROPICAL FRUIT                         BANANAS
# ...

# %%
products.query("PRODUCT_ID == 1082185")
# Out:
#        PRODUCT_ID  MANUFACTURER DEPARTMENT     BRAND  COMMODITY_DESC  \
# 35576     1082185             2    PRODUCE  National  TROPICAL FRUIT
#
#       SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 35576            BANANAS                40 LB
